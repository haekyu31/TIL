# %% [markdown]
# # 1. 그래프와 시각화

# %% [markdown]
# - 막대 그래프
# - 히스토그램
# - 선 그래프
# - 산점도

# %% [markdown]
# ## 막대 그래프
# - 막대 그래프는 범주별로 도수, 횟수, 퍼센트 등의 크기만큼 막대를 그리는 그래프
# - 범주별 미세한 차이를 명확하게 전달할 수 있는 그래프

# %% [markdown]
# ### 막대 그래프 예제
# - 영화별 아카데미 수상 횟수
# <p>
# <table cellspacing="20">
# <tr>
#     <td>영화 제목</td>
#     <td>Annie Hall</td>
#     <td>Ben-Hur</td>
#     <td>Casablanca</td>
#     <td>Gandhi</td>
#     <td>West Side Story</td>
# </tr>
# <tr>
#     <td>수상 횟수</td>
#     <td>5</td>
#     <td>11</td>
#     <td>3</td>
#     <td>8</td>
#     <td>10</td>
# </tr>
# </table>
# </p>

# %% [markdown]
# * x 축: 범주(영화 제목)
# * y 축: 도수(수상 횟수)

# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
# plt.bar(range(len(movies)), num_oscars)
# plt.xticks(range(len(movies)), movies) #x축의 레이블 값 변경
plt.bar(movies, num_oscars)
plt.xticks(movies)
plt.ylabel("Academy Awards")  #y축 label값
plt.xlabel("Actor Name")   #x축 label값
plt.show()  # 그래프 출력 함수를 적어줘야한다
# plt.bar([0,1,2,3,4], num_oscars)
# plt.bar(movies, num_oscars)

# %% [markdown]
# ### 막대 그래프 유의사항
# - X 축과 Y축을 지정할때는 주의해야 한다.

# %% [markdown]
# - 2017년과 2018년 사람들이 데이터 과학에 대해 언급하는 것을 경험한 횟수
# <table>
# <tr>
#     <td>연도</td>
#     <td>2017</td>
#     <td>2018</td>
# </tr>
# <tr>
#     <td>횟수</td>
#     <td>500</td>
#     <td>505</td>
# </tr>
# </table>

# %% [markdown]
# #### y축의 시작을 499로 잡는 경우

# %%
mentions = [500,505]
years = [2017, 2018]

# %% [markdown]
# # pyplot 한글 깨짐
# # colab
# ```
# !sudo apt-get install -y fonts-nanum #다른 font사용해도됨
# !sudo fc-cache -fv #캐시 제거
# !rm ~/.cache/maplotlib -rf
#
# ```

# %%
plt.bar(years, mentions)
plt.xticks(years)
plt.ylabel("data science")
plt.xlabel("Year")

#축의 정보를 결정
plt.axis([2016.5,2018.5,499,506])  

plt.title("data science")  #한글은 오류가 나옴
plt.show()

# %% [markdown]
# #### y축의 시작을 0으로 잡는 경우

# %% [markdown]
# ## 히스토그램

# %% [markdown]
# - 막대 그래프의 한 종류
# - 양적 데이터를 범주로 사용할 때 유용하다.
#     - 예를 들어, 무게, 길이, 시간, 점수 등
#
# - 숫자의 범위에 따라 나뉘어진 데이터를 막대 그래프로 보여줄 때 사용한다.
#     - 양적 데이터들의 연속성을 반영하기 위해 막대 그래프들 사이의 간극이 없도록 표현한다.
#     - 정해진 구간에 해당되는 항목의 개수나 빈도수를 보여주어 값의 분포를 쉽게 관찰
#
# __참고__
# - 질적 자료
#     - 사칙 연산이 불가능
#     - 비계측 자료(Nonmetric Data) 혹은 범주형 자료(Categorical Data)
#     - 예) 직업, 종교, 성별
#
# - 양적 자료
#     - 사칙 연산 가능
#     - 계측 자료(Metric Data) 혹은 숫자형 자료(Numerical Data)
#     - 예) 몸무게, 용돈, 가격

# %% [markdown]
# ### 히스토그램 예제
#
# 학생들의 점수가 다음과 같다.
#
#     83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0
#
# 점수를 십분위수(10점 단위로 구분)로 구분하면 아래 표를 얻는다.

# %% [markdown]
# <p>
# <table cellspacing="20">
# <tr>
#     <td>점수 구간(십분위수)</td>
#     <td>0-9</td>
#     <td>10-19</td>
#     <td>20-29</td>
#     <td>30-39</td>
#     <td>40-49</td>
#     <td>50-59</td>
#     <td>60-69</td>
#     <td>70-79</td>
#     <td>80-89</td>
#     <td>90-100</td>
# </tr>
# <tr>
#     <td>학생 수</td>
#     <td>2</td>
#     <td>0</td>
#     <td>0</td>
#     <td>0</td>
#     <td>0</td>
#     <td>0</td>
#     <td>1</td>
#     <td>3</td>
#     <td>4</td>
#     <td>3</td>
# </tr>
# </table>
# </p>

# %% [markdown]
# 위 데이터를 히스토그램으로 나타내면 다음과 같다.

# %% [markdown]
# * x 축: 점수 구간
# * y 축: 학생 수

# %%
from collections import Counter
grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

histogram = Counter(min(grade // 10 * 10, 90) for grade in grades)

# %%
plt.bar(histogram.keys(),
        histogram.values())
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
np.array(list(histogram.keys()), dtype= np.int64)+5
# Out:
# array([85, 95, 75,  5, 65], dtype=int64)

# %%
# bar 를 이용해 hist를 만들기

plt.bar(np.array(list(histogram.keys()), dtype= np.int64)+5,
        histogram.values(),
        width=10,
        edgecolor = (0,0,0))

plt.xticks(np.arange(0,101,10))
plt.axis([-5, 105, 0, 5])
plt.xlabel("score")
plt.ylabel("of students")
plt.show()

# %%
#hist()를 이용

plt.hist(grades,
         width = 10,
         edgecolor = (0,0,0))

plt.xticks(np.arange(0,101,10))
plt.axis([-5, 105, 0, 5])
plt.xlabel("score")
plt.ylabel("of students")
plt.show()

# %%
plt.hist(grades,
         width = 5,
         bins = 20,  #bins를 이용 구간을 더 나눌수있다
         edgecolor = (0,0,0))

plt.xticks(np.arange(0,101,5))
plt.axis([-5, 105, 0, 5])
plt.xlabel("score")
plt.ylabel("of students")
plt.show()

# %% [markdown]
# ## 선 그래프

# %% [markdown]
# 선 그래프는 막대 그래프의 상단 중심부를 선분으로 연결하여 범주별 변화를 비교하는 그래프이다.
# 시계열 데이터에 대한 정보를 전달할 때 유용하다.
# [plt.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %% [markdown]
# ### 선 그래프 예제
#
# 1950년 부터 10년 주기로 미국 국내총생산(GDP)를 정리한 표가 다음과 같다.
# 단위는 10억달러이다.

# %% [markdown]
# 위 데이터를 선 그래프로 나타내면 다음과 같다.

# %% [markdown]
# <p>
# <table cellspacing="20">
# <tr>
#     <td>연도</td>
#     <td>1950</td>
#     <td>1960</td>
#     <td>1970</td>
#     <td>1980</td>
#     <td>1990</td>
#     <td>2000</td>
#     <td>2010</td>
# </tr>
# <tr>
#     <td>GDP</td>
#     <td>300.2</td>
#     <td>543.3</td>
#     <td>1075.9</td>
#     <td>2862.5</td>
#     <td>5979.6</td>
#     <td>10289.7</td>
#     <td>14958.3</td>
# </tr>
# </table>
# </p>

# %% [markdown]
# * x 축: 연도
# * y 축: GDP

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
plt.plot(years, 
         gdp,
         "--",
         color = (0,0,0),
         marker = "o")

# %%
plt.plot(years, 
         gdp,
         "-.",
         color = 'r',
         marker = "s")

# %%
plt.plot([1,2,3],[1,1,1],"-", color = "b")
plt.plot([1,2,3],[2,2,2],":", color = "r")
plt.plot([1,2,3],[3,3,3],"-.", color = "y")
plt.plot([1,2,3],[4,4,4],"--.", color = "g")

# %%
# plt.plot([1,2,3,4,5],[1,2,1,1,1],"-",color = "m")  #1,2,3,4,5를 x축 1,2,1,1,1이 y값을 가지기 때문에
#갯수가 맞아야 한다

# %% [markdown]
# ## 산점도
# - [참고](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html?highlight=scatter#matplotlib.pyplot.scatter)

# %% [markdown]
# 산점도는 두 변수 간의 연관 관계를 2차원 평면 상에서 점으로 찍어 보여 주는 그래프이다.

# %% [markdown]
# ### 산점도 예제
#
# 어떤 웹사이트 회원의 친구 수와 하룻동안의 사이트 이용시간 사이의 연관 관계를 담은 표가 다음과 같다.

# %% [markdown]
# <p>
# <table cellspacing="20">
# <tr>
#     <td>친구 수</td>
#     <td>70</td>
#     <td>65</td>
#     <td>72</td>
#     <td>63</td>
#     <td>71</td>
#     <td>64</td>
#     <td>60</td>
#     <td>64</td>
#     <td>67</td>
# </tr>
# <tr>
#     <td>이용 시간</td>
#     <td>175</td>
#     <td>170</td>
#     <td>205</td>
#     <td>120</td>
#     <td>220</td>
#     <td>130</td>
#     <td>105</td>
#     <td>145</td>
#     <td>190</td>
# </tr>
# <tr>
#     <td>사용자 라벨</td>
#     <td>a</td>
#     <td>b</td>
#     <td>c</td>
#     <td>d</td>
#     <td>e</td>
#     <td>f</td>
#     <td>g</td>
#     <td>h</td>
#     <td>i</td>
# </tr>
# </table>
# </p>

# %% [markdown]
# 위 데이터를 선 그래프로 나타내면 다음과 같다.

# %% [markdown]
# * x 축: 친구 수
# * y 축: 이용 시간

# %%
friends = [ 70,  65,  72,  63,  71,  64,  60,  64,  67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels =  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# %%
plt.scatter(friends, minutes, s=50)
plt.annotate("a",
             xy =(70,175),
             size =20 )
# Out:
# Text(70, 175, 'a')

# %%
plt.scatter(friends, minutes)
for i, j, k in zip(labels, friends, minutes):    
    plt.annotate(i,
                 xy =(j,k),
                 xytext = (5, -5),
                 textcoords = "offset points")
    
plt.xlabel("friends")
plt.ylabel("minutes on the site")
plt.title("minutes per friends")
plt.show()

# %%
x = np.random.rand(30)
y = np.random.rand(30)
area = (y*300)
colors = (y*10)

plt.scatter(x,y, s = area, c=colors)

# %%
x = np.random.rand(50)
y = np.random.rand(50)
area = (y*200)
colors = (y*50)

plt.scatter(x,y, s = area, c=colors,alpha = 0.78,marker = "*", cmap = "Spectral")
plt.colorbar()
#cmap은 colormap을 의미
#alpha 투명도

# %% [markdown]
# ### 산점도 유의사항
# - 막대 그래프의 경우처럼 축을 지정시 유의해야함

# %% [markdown]
# - 예) 다섯 명의 1차, 2차 테스트 점수
# <p>
# <table cellspacing="20">
# <tr>
#     <td>1차 테스트</td>
#     <td>99</td>
#     <td>90</td>
#     <td>85</td>
#     <td>97</td>
#     <td>80</td>
# </tr>
# <tr>
#     <td>2차 테스트</td>
#     <td>100</td>
#     <td>85</td>
#     <td>60</td>
#     <td>90</td>
#     <td>70</td>
# </tr>
# </table>
# </p>

# %% [markdown]
# #### 축 지정
#
# * x 축: 1차 테스트 점수
# * y 축: 2차 테스트 점수

# %% [markdown]
# #### 양 축의 척도(scale)가 다른 경우

# %%
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

# %%
plt.scatter(test_1_grades, test_2_grades)
plt.show()

# %% [markdown]
# 결론: 1차 테스트, 2차 테스트 점수가 별 변동이 없는 것으로 보인다.

# %% [markdown]
# #### 양 축의 척도가 동일한 경우

# %%
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

# %% [markdown]
# 결론: 1차 테스트 점수가 높은 친구가 2차 테스트에서 보다 높은 점수를 얻었음을 알 수 있다.

# %%
plt.scatter(test_1_grades, test_2_grades)
plt.axis([50,110,50,110])
plt.show()

# %% [markdown]
# 결론: 1차 테스트 점수가 높은 친구가 2차 테스트에서 보다 높은 점수를 얻었음을 알 수 있다.

# %%
plt.scatter(test_1_grades, test_2_grades)
plt.axis("equal")
plt.show()

# %% [markdown]
# # 2. 그래프와 시각화

# %% [markdown]
# ## 기본 설정

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.set_printoptions(precision=4, suppress=True)
np.random.seed(12345)

# %%
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 6))  # 그림 크기 설정

# %% [markdown]
# ## matplotlib.pyplot의 시각화 도구 API

# %% [markdown]
# ### `matplotlib.pyplot.plot()`
# - 2차원 그래프를 그리는 함수이다.
# - y축 좌표들의 리스트 또는 어레이만 인자로 넣어줄 때이다. x축 좌표는 해당 값들의 인덱스로 사용됨
# - [참고](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)
# -3D도 가능

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


def randrange(n, vmin, vmax):
    """
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    """
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for m, zlow, zhigh in [('o', -50, -25), ('^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
data = np.arange(10)
plt.plot(data)

# %% [markdown]
# ### `Figure` 객체와 서브플롯(subplot)

# %% [markdown]
# - 모든 그래프는 `Figure` 객체 내에 존재
# - `matplotlib.pyplot.figure()` 함수에 의해 생성

# %% [markdown]
# __참고:__
# - 주피터 노트북을 사용시  `matplotlib.pyplot.figure()`, `matplotlib.pyplot.add_subplot()` 등 그래프를 그래프화 관련된 함수들은 모두 같은 셀에서 실행되어야 한다.

# %%
#같은 셀 안에 있어야 동작을 한다

fig = plt.figure()
fig.add_subplot(2,2,1)
plt.show()

# %%
fig = plt.figure()

# %%
fig.add_subplot(2,2,1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 서브플롯(subplot)
#     - `Figure` 객체 내에 그래프를 그리기 위해 서브플롯(subplot)을 지정
#     - `add_subplot()` 함수를 이용하여 지정된 `Figure` 객체안에 그래프를 그릴 공간을 만들어 보자

# %%
fig = plt.figure()
fig.add_subplot(2,2,1)
fig.add_subplot(2,2,2)
fig.add_subplot(2,2,3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - subplot 추가

# %% [markdown]
# #### 그래프 삽입
# - `matplotlib.pyplot.plot()`
# - `<object>.plot()`

# %% [markdown]
# ##### 방법 1: `matplotlib.pyplot.plot()`

# %% [markdown]
# - 마지막에 선언된 서브플롯에 그래프를 그린다.
# - 예) 누적합을 나타내는 그래프를 그려보자

# %%
import numpy as np
data = np.random.randn(40).cumsum() #누적합

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)  #2x2인 subplot을 만들어준다
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

plt.plot(data, "-.")  #마지막에 그려진다

# %% [markdown]
# ##### 방식 2: `객체명.plot()` 함수 활용

# %% [markdown]
# - 특정 서브플롯에 그래프를 삽입하려면 객체 이름과 함께 `plot()` 함수 등을 호출

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)  #2x2인 subplot을 만들어준다
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

#위치 지정
ax3.plot(data, "-.") #plt.plot 는 마지막plot를 의미한다
ax1.plot(data, ":")  #(2,2,1)의 위치에 plot을 출력한다
ax2.scatter(np.arange(20),np.arange(20)+np.random.randn(20))  #(2,2,2)의 위치에 출력한다
plt.show()

# %% [markdown]
# #### 서브플롯 관리

# %% [markdown]
# - `matplotlib.pyplot.subplots()`
#     - 여러 개의 서브플롯을 포함하는 `Figure` 객체를 관리해준다.
#
# - 예) 2x3 크기의 서브플롯을 담은 (2,3) 모양의 넘파이 어레이로 생성.

# %%
fig,axes =  plt.subplots(2,3)
print(fig)
print(axes)
# Out:
# Figure(720x432)
# [[<AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]]

# %% [markdown]
# - `plt.subplots_adjust()`
#     - 각 서브플롯 사이의 여백을 조절
#     - 여백의 크기는 그래프의 크기와 숫자에 의존한다.

# %% [markdown]
# - 예) 여백이 0인 경우

# %%
fig, axes = plt.subplots(2,3)
plt.subplots_adjust(wspace= 0, hspace = 0)

# %% [markdown]
# - 예) 여백이 1인 경우

# %%
fig, axes = plt.subplots(2,3)
plt.subplots_adjust(wspace= 1, hspace = 1)

# %%
fig, axes = plt.subplots(2,3)
plt.subplots_adjust(wspace= 0.3, hspace = 0.07)

# %% [markdown]
# ### 색상, 마커, 선 스타일

# %% [markdown]
# - 그래프의 속성을 변경하면 스타일이 변경된다.
# - 방법 1: 문자열 방식
#
# ```python
# ax.plot(x, y, 'g--')
# ```

# %% [markdown]
# - 방법 2: 키워드 인자 지정 방식
#
# ```python
# ax.plot(x, y, linestyle='--', color='g')
# ```

# %% [markdown]
# 색상은 RGB 값을 HEX 코드를 이용하여 직접 사용 가능
# - [RGB HEX 코드 link](https://www.w3schools.com/colors/colors_rgb.asp)

# %% [markdown]
# #### 여러 그래프 하나의 서브플롯에 그리기

# %% [markdown]
# - 여러 스타일의 그래프를 하나의 서브플롯에 그려 다양한 정보를 동시에 전달

# %%
plt.plot(data, "--")

# %%
plt.plot(data, drawstyle = "steps-post", color = "m")

# %%
plt.plot(data, drawstyle = "steps-post", color = "m", label = "steps-post")
plt.plot(data, "--", label = "default")

# %% [markdown]
# - 범례 표기
#     - `plt.legend()`
#     - `loc='best'`: 범례 위치 지정. 기본값은 auto

# %%
plt.plot(data, drawstyle = "steps-post", color = "m", label = "steps-post")
plt.plot(data, "--", label = "default")
plt.legend(loc = "best")  #label위치 표기  loc = "best"는 가장 좋은 위치에

#upper left
#upper right

# %% [markdown]
# ### 눈금과 라벨

# %% [markdown]
# #### 이미지 타이틀, 축 이름, 눈금, 눈금 이름 지정

# %% [markdown]
# ##### 방법 1: 파이플롯 객체의 메서드 활용
# - `set_xticks()` 함수: 눈금 지정
# - `set_xticklabels()` 함수: 눈금 라벨 지정
# - `set_title()` 함수: 그래프 타이틀 지정
# - `set_xlabel()` 함수: x축 이름 지정

# %%
data = np.random.randn(1000).cumsum()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot(data)

ax1.set_xticks(np.arange(0,1001,100))
ax1.set_xticklabels(["one", "two", "three", "four","five", "six", "seven","eight", "nine","ten","eleven"],
                    size = 20,
                    rotation = 30) #기울이기
plt.show()

# %% [markdown]
# ##### 방법 2: pyplot 모듈의 함수 활용
# - `plt.xticks()` 함수: 눈금 및 눈금 라벨 지정
# - `plt.title()` 함수: 그래프 타이틀 지정
# - `plt.xlabel()` 함수: x축 이름 지정

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot(data)

plt.xticks(np.arange(0,1001,100),
           ["one", "two", "three", "four","five", "six", "seven","eight", "nine","ten","eleven"],
           size = 20,
           rotation = 30)
plt.show()

# %% [markdown]
# ### 서브플롯에 주석 및 도형 추가하기

# %% [markdown]
# #### 주석 추가

# %% [markdown]
# 설명을 위해 S&P 500 (스탠다드 앤 푸어스, Standard and Poor's 500)의 미국 500대 기업을 포함한
# 주식시장지수 데이터로 그래프를 생성하고 2007-2008년 사이에 있었던
# 재정위기와 관련된 중요한 날짜를 주석으로 추가한다.

# %%
spx_path = "https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/examples/spx.csv"

# %%
data = pd.read_csv(spx_path, index_col = 0, parse_dates= True)

# %%
data
# Out:
#                 SPX
# Date
# 1990-02-01   328.79
# 1990-02-02   330.92
# 1990-02-05   331.85
# 1990-02-06   329.66
# 1990-02-07   333.75
# ...             ...
# 2011-10-10  1194.89
# 2011-10-11  1195.54
# 2011-10-12  1207.25
# 2011-10-13  1203.66
# 2011-10-14  1224.58
#
# [5472 rows x 1 columns]

# %% [markdown]
# 시간 컬럼을 행의 인덱스로 사용하자
#
# - `index_col=0`: 0번 열(column)을 인덱스로 사용
# - `parse_dates=True`: 년월일까지만 구분해서 인덱스로 사용. 기본값은 `False`.

# %%
data.index
# Out:
# DatetimeIndex(['1990-02-01', '1990-02-02', '1990-02-05', '1990-02-06',
#                '1990-02-07', '1990-02-08', '1990-02-09', '1990-02-12',
#                '1990-02-13', '1990-02-14',
#                ...
#                '2011-10-03', '2011-10-04', '2011-10-05', '2011-10-06',
#                '2011-10-07', '2011-10-10', '2011-10-11', '2011-10-12',
#                '2011-10-13', '2011-10-14'],
#               dtype='datetime64[ns]', name='Date', length=5472, freq=None)

# %% [markdown]
# - 위 데이터를 그래프로 나타내 보자

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
data.plot(ax = ax1)
plt.show()

# %% [markdown]
# 2007-2008년 세계적 금융위기 지점을 아래 내용으로 그래프에 주석으로 추가해보자.
#
# - 2007년 10월 11일: 주가 강세장 위치 'Peak of bull market'
# - 2008년 3월 12일: 베어스턴스 투자은행 붕괴 'Bear Stearns Fails'
# - 2008년 9월 15일: 레만 투자은행 파산 'Lehman Bankruptcy'

# %%
data.asof(datetime(2007,10,11))
# Out:
# SPX    1554.41
# Name: 2007-10-11 00:00:00, dtype: float64

# %%
from datetime import datetime
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
data.plot(ax = ax1)
ax1.annotate("Peak of bull market", 
             xy = (datetime(2007,10,11),data.asof(datetime(2007,10,11))),
             arrowprops = dict(facecolor = 'black', headlength = 4),
             horizontalalignment='left', verticalalignment='top')
ax1.set_ylim([600,1800])
plt.show()

# %% [markdown]
# #### `annotate()`

# %% [markdown]
# - `xt` 속성: 화살표 머리 위치
# - `xytext` 속성: 텍스트 위치
# - `arrowprops` 속성: 화살표 속성
# - `horizontalalignment`: 텍스트 좌우 줄맞춤
# - `verticalalignment`: 텍스트 상하 줄맞춤

# %%
## 그림 그리기 
# https://frhyme.github.io/python-lib/plt_arrowprops/
plt.figure(figsize=(12, 6))
plt.annotate('dd', ## 텍스트
             
             xy=(0.1, 0.4), ## 화살이 가르킬 위치 
             xytext=(0.8, 0.6), ## 텍스트 위치 
             fontsize=40, ## font 크기 
             arrowprops=dict(facecolor='red', ## 내부 색깔 
                             edgecolor='black', ## 선 색깔 
                             fill=True, ## 내부가 비어짐(fill white와 같은 )
                             shrink=0.15, ## 텍스트로부터 얼마나 떨어진 위치에서 화살표가 시작하는가? 0이 최소 1이 최대  
                             headwidth=80, ## 화살 너비
                             headlength=100, ## 화살 길이 
                             width=30, ## 화살표에서 화살이 아닌 부분의 너비  
                             linewidth=10, ## polygon의 선 
                             linestyle=':', ## 선의 특성 
                             alpha=0.8, ## 투명도, line, fill을 따로 지정할 수 있는지는 모르겠음. 
                             )
            )
# Out:
# Text(0.8, 0.6, 'dd')

# %%
data = pd.read_csv(spx_path, index_col=0, parse_dates = True)
spx = data["SPX"]

# %%
crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

spx.plot(ax=ax, style='k-')

for date, label in crisis_data:
    ax.annotate(label, 
                xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

ax.set_xlim([datetime(2007, 1, 1), datetime(2011, 12, 31)])
ax.set_ylim([600, 1800])
plt.show()

# %% [markdown]
# #### 도형 추가

# %% [markdown]
# 지정된 함수를 이용하여 다양한 도형을 추가 가능
#
# - `plt.<도형명>((위치), 크기)`
# - `plt.Rectangle()`: 직사각형. 왼편 아래 좌표 및 가로 세로 길이
# - `plt.Circle()`: 원. 원의 중심 좌표 및 반지름.
# - `plt.Polygon()`: 다각형. 각 꼭지점의 좌표.

# %% [markdown]
# __주의사항:__
# - x, y축의 눈금이 다르면 도형이 정확하게 표현되지 않을 수 있다.
# - 예를 들어, 두 축의 척도가 다르면 원이 타원으로 보일수 있음
#     - `Figure` 객체를 생성할 때 두 축의 크기를 동일하게 지정하면 척도가 동일해 진다.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)
rect = plt.Rectangle((1, 2), width=3, height=1) #사각형 객체 생성후 
circ = plt.Circle((8,6), 1)

pgon = plt.Polygon(([4,4], [4,6], [6,6], [6,2]))


ax.set_xlim(0,10)
ax.set_ylim(0,10)
ax.add_patch(rect)# 객체 추가
ax.add_patch(circ)
ax.add_patch(pgon)
plt.show()

# %%
fig = plt.figure(figsize=(4,6))
ax = fig.add_subplot(1,1,1)

ax.scatter(np.random.randn(50), np.random.randn(50)+3)
pg = plt.Polygon(([0, 3],[1, 4],[0, 5]), alpha=0.2)
ax.add_patch(pg)

# %% [markdown]
# ### 그래프 저장하기

# %% [markdown]
# `plt.savefig()`
#
# - `dpi=100`: 인치당 픽셀 수. 저장된 이미지의 해상도 지정.
# - `bbox_inches=tight`: 이미지별 둘레의 공백 지정. 여기서는 공백을 거의 사용하지 말라는 의미임.

# %%
fig = plt.figure(figsize=(4,6))
ax = fig.add_subplot(1,1,1)

ax.scatter(np.random.randn(50), np.random.randn(50)+3)
pg = plt.Polygon(([0, 3],[1, 4],[0, 5]), alpha=0.2)
ax.add_patch(pg)
plt.savefig("hello.png")

# %% [markdown]
# ### matplotlib 기본 설정

# %% [markdown]
# `plt.rc()` 함수를 이용하여 matplot을 이용하여 생성되는 이미지 관련 설정을 전역적으로 지정할 수 있다.
# 사용되는 형식은 다음과 같다.
#
# - 첫째 인자: 속성 지정
# - 둘째 인자: 속성값 지정
#
# __참고:__ 'rc' 는 기본설정을 의미하는 단어로 많이 사용된다.
# 풀어 쓰면 "Run at startup and they Configure your stuff",
# 즉, "프로그램이 시작할 때 기본값들을 설정한다"의 의미이다.
# '.vimrc', '.bashrc', '.zshrc' 등 많은 애플리케이션의 초기설정 파일명에 사용되곤 한다.
#
# 아래 코드는 이미지의 사이즈를 지정한다.

# %%
plt.rc('figure', figsize=(10, 10))

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
plt.show()

# %% [markdown]
# 아래 코드는 다양한 속성을 지정하는 방식을 보여준다.

# %% [markdown]
# * 이미지 사이즈 지정

# %%
plt.rc("figure", figsize=(10,6))

# %% [markdown]
# * 선 속성 지정

# %%
plt.rc("lines", linewidth=3, color="r")

# %% [markdown]
# * 텍스트 폰트 속성 지정

# %%
# font_options = {
#     "family":"fontname",
#     "weight" : "bold"
#     "size": "size값"
# }
# plt.rc("font", <font_options>)

# %% [markdown]
# * 그래프 구성 요소의 색상 지정

# %%
plt.rcParams["text.color"] = "black"
plt.rcParams["xtick.color"] = "red"

# %% [markdown]
# 아래 코드는 앞서 설정된 다양한 속성을 반영한 결과를 보여준다.

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

spx.plot(ax=ax, style='-')

for date, label in crisis_data:
    ax.annotate(label, 
                xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

plt.show()

# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1.필요한 librarie들을 import 하세요

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### Step 2. 다음과 같은 DataSet을 import 하세요 [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv'
apple = pd.read_csv(url)
apple   #이미 넣는순간 데이터 프레임 형태
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 3. apple 라는 변수에 DataFrame을 할당 하세요

# %%
apple = pd.DataFrame(apple)
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 4. 각 column들의 data type을 확인하세요

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### Step 5. Date column을 datetime type으로 변경하세요

# %%
apple.Date = pd.to_datetime(apple.Date)
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %% [markdown]
# ### Step 6. Date column을 index로 설정하세요

# %%
apple.set_index('Date', inplace = True)
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### Step 7. 중복된 date가 존재 하는지 확인하세요

# %%
apple.index.is_unique
# Out:
# True

# %% [markdown]
# ### Step 8. index를 오름차순으로 정렬하세요.

# %%
# apple.index = apple.index.sort_values()  인덱스를 고르고 그다음 value를 구하는 방식 sort_index와 같다
apple.sort_index(ascending = True, inplace = True)

# %%
apple.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %% [markdown]
# ### Step 9. 매월 마지막 영업일 가져오세요 (business day of each month)

# %%
apple.resample('BM').last()
# apple.resample('BM').mean()
# apple.resample('BM').sum()
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-31   34.25   34.25   34.13   34.13    8937600       0.53
# 1981-01-30   28.50   28.50   28.25   28.25   11547200       0.44
# 1981-02-27   26.50   26.75   26.50   26.50    3690400       0.41
# 1981-03-31   24.75   24.75   24.50   24.50    3998400       0.38
# 1981-04-30   28.38   28.62   28.38   28.38    3152800       0.44
# ...            ...     ...     ...     ...        ...        ...
# 2014-03-31  539.23  540.81  535.93  536.74   42167300      76.25
# 2014-04-30  592.64  599.43  589.80  590.09  114160200      83.83
# 2014-05-30  637.98  644.17  628.90  633.00  141005200      90.43
# 2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
# 2014-07-31   96.27   96.80   93.92   95.35   65130000      95.35
#
# [404 rows x 6 columns]

# %% [markdown]
# ### Step 10. 주가가 등록된 첫날과 마지막 날의 차이는 몇일인가요?

# %%
apple.index[-1] -apple.index[0]
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# ### Step 11. 영업달 기준으로 몇달간의 데이터가 저장되어있나요?

# %%
len(apple.resample('BM').count())  #영업월 기준으로 샘플링해서 간격을 정하고
#월별로 중복되지 않도록 숫자를 세고 
#총 길이를 구해서 몇달간의 데이터가 저장되어있는지 확인한다
# Out:
# 404

# %% [markdown]
# ### Step 12. 'Adj Close'값을 이용해 종가 그래프를 그려보세요
# - `plt.plot`
# - 코드를 강사와 공유해 보세요

# %%
fig = plt.figure()   #빈 플롯을 만들기 위해서
fig.set_size_inches(10,5)
plt.subplots_adjust(hspace =0.5)
apple_1 = fig.add_subplot(2,1,1)  # 2,1,1번째 그래프
apple_1.plot(apple.index, apple["Adj Close"])

apple_2 = fig.add_subplot(2,1,2)  # 2,1, 2번째 그래프
apple_2.plot(apple.index, apple["Volume"], drawstyle = "steps-post", color = 'm')


plt.show()

# %%
#x축은 공유하고 y축은 두개를 쓰는 방법

fig = plt.figure()
fig.set_size_inches(15,5)
apple_1 = fig.add_subplot(1,1,1)
apple_1.plot(apple.index, apple["Adj Close"], color = 'r')

apple_2 = apple_1.twinx()  #같은 x축을 공유하다
apple_2.plot(apple.index, apple["Volume"], drawstyle = "steps-post", color = 'y', alpha = 0.5)
apple_2.set_ylim([0,apple['Volume'].max()*2])

plt.show()

# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. 필요한 라이브러리 들을 import 하세요

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### Step 2. 다음 주소의 파일을 import 하세요 [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
type(chipo)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Step 3. chipo 라는 변수에 DataFrame 을 할당하세요

# %%
chipo = pd.DataFrame(chipo)
type(chipo)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. 구매 상위 5개 품목의 히스토그램을 생성하세요
# - collections 의 Counter 를 사용하세요

# %% [raw]
# # chipo.groupby('item_name').sum().sort_values('quantity', ascending = False).head()
# q_list = chipo.groupby('item_name').sum().sort_values('quantity', ascending = False)
# item_sum = chipo.groupby(by = 'item_name').sum()
# top_5 = item_sum.sort_values('quantity', ascending = False).head(5)
# top_5 =top_5.to_dict()['quantity']
# _5key=list(top_5.keys())
# _5value=list(top_5.values())
# plt.plot(_5key.keys(), _5value.values())
#
# 결과는 같다 다만 지저분함

# %%
from collections import Counter

# %%
x = chipo.item_name

# %%
print(x)

#type(x)  # x열의 값을 보여주기때문에 pd.Series가 된다.
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
best_items = dict(Counter(chipo.item_name).most_common(5))  #count로 세면 요소가 몇번 등장했는지 알 수있다.

# %%
plt.bar(list(best_items.keys()),list(best_items.values()))
plt.xticks(list(best_items.keys()), rotation = 30)   #눈금표시
plt.xlabel("items")
plt.ylabel("Number of")
plt.title("Most ordered")
plt.show()

# %%
#히스토그램은 구간을 정해줘야 한다

# %%
# item_counts = Counter(x)
# df = pd.DataFrame.from_dict(item_counts, orient = 'index')
# df[0].sort_values(ascending = False)[:5]

# %%
# chipo.groupby('item_name').count()

# %% [markdown]
# ### Step 6. 주문가격당 주문횟수를 산점도를 생성하여 확인하시오
# #### Hint: 주문 가격은 X축, 주문 횟수는Y축

# %%
chipo.item_price = [float(i[1:-1]) for i in chipo.item_price]

# %%
order = chipo.groupby("order_id").sum()

# %%
x = order.item_price
y = order.quantity

# %%
plt.scatter(x,y)
plt.xlabel("order price")
plt.ylabel("order items")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [raw]
# pd Series 는 딕셔너리 같은 pd DataFrame 은 매트릭스같은
#
# sort_index   인덱스 값으로 데이터 프레임을 정렬
# sort _values    sum mean max min 을 쓸수있다
#
# value_counts  column에서 1번씩 등장하도록 세는것
#
# xtick() 눈금표시
